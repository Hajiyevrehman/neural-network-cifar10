# %% [markdown]
#  Classification using Neural Network
#
# Now that you have developed and tested your model on the toy dataset set. It's time to get down and get dirty with a standard dataset such as cifar10. At this point, you will be using the provided training data to tune the hyper-parameters of your network such that it works with cifar10 for the task of multi-class classification.

# %%
# Prepare Packages
import numpy as np
import matplotlib.pyplot as plt

from utils.data_processing import get_cifar10_data
from utils.evaluation import get_classification_accuracy


# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # set default size of plots

# For auto-reloading external modules
# See http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# Use a subset of CIFAR10 for the assignment
dataset = get_cifar10_data(
    subset_train=5000,
    subset_val=250,
    subset_test=500,
)

print(dataset.keys())
print("Training Set Data  Shape: ", dataset["x_train"].shape)
print("Training Set Label Shape: ", dataset["y_train"].shape)
print("Validation Set Data  Shape: ", dataset["x_val"].shape)
print("Validation Set Label Shape: ", dataset["y_val"].shape)
print("Test Set Data  Shape: ", dataset["x_test"].shape)
print("Test Set Label Shape: ", dataset["y_test"].shape)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# dict_keys(['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test'])
# Training Set Data  Shape:  (5000, 3072)
# Training Set Label Shape:  (5000,)
# Validation Set Data  Shape:  (250, 3072)
# Validation Set Label Shape:  (250,)
# Test Set Data  Shape:  (500, 3072)
# Test Set Label Shape:  (500,)

# %%
x_train = dataset["x_train"]
y_train = dataset["y_train"]
x_val = dataset["x_val"]
y_val = dataset["y_val"]
x_test = dataset["x_test"]
y_test = dataset["y_test"]

# %%
# Import more utilies and the layers you have implemented
from layers.sequential import Sequential
from layers.linear import Linear
from layers.relu import ReLU
from layers.softmax import Softmax
from layers.loss_func import CrossEntropyLoss
from utils.optimizer import SGD
from utils.dataset import DataLoader
from utils.trainer import Trainer

# %% [markdown]
# ## Visualize some examples from the dataset.

# %%
# We show a few examples of training images from each class.
classes = [
    "airplane",
    "automobile",
    "bird",
    "cat",
    "deer",
    "dog",
    "frog",
    "horse",
    "ship",
]
samples_per_class = 7


def visualize_data(dataset, classes, samples_per_class):
    num_classes = len(classes)
    for y, cls in enumerate(classes):
        idxs = np.flatnonzero(y_train == y)
        idxs = np.random.choice(idxs, samples_per_class, replace=False)
        for i, idx in enumerate(idxs):
            plt_idx = i * num_classes + y + 1
            plt.subplot(samples_per_class, num_classes, plt_idx)
            plt.imshow(dataset[idx])
            plt.axis("off")
            if i == 0:
                plt.title(cls)
    plt.show()


# Visualize the first 10 classes
visualize_data(
    x_train.reshape(5000, 3, 32, 32).transpose(0, 2, 3, 1),
    classes,
    samples_per_class,
)

# %% [markdown]
# ## Initialize the model

# %%
input_size = 3072
hidden_size = 100  # Hidden layer size (Hyper-parameter)
num_classes = 10  # Output

# For a default setting we use the same model we used for the toy dataset.
# This tells you the power of a 2 layered Neural Network. Recall the Universal Approximation Theorem.
# A 2 layer neural network with non-linearities can approximate any function, given large enough hidden layer
def init_model():
    # np.random.seed(0) # No need to fix the seed here
    l1 = Linear(input_size, hidden_size)
    l2 = Linear(hidden_size, num_classes)

    r1 = ReLU()
    softmax = Softmax()
    return Sequential([l1, r1, l2, softmax])

# %%
# Initialize the dataset with the dataloader class
dataset = DataLoader(x_train, y_train, x_val, y_val, x_test, y_test)
net = init_model()
optim = SGD(net, lr=0.01, weight_decay=0.01)
loss_func = CrossEntropyLoss()
epoch = 200  # (Hyper-parameter)
batch_size = 200  # (Reduce the batch size if your computer is unable to handle it)

# %%
# Initialize the trainer class by passing the above modules
trainer = Trainer(
    dataset, optim, net, loss_func, epoch, batch_size, validate_interval=3
)

# %%
# Call the trainer function we have already implemented for you. This trains the model for the given
# hyper-parameters. It follows the same procedure as in the last ipython notebook you used for the toy-dataset
train_error, validation_accuracy = trainer.train()
# Out:
# Epoch Average Loss: 2.302537
# Validate Acc: 0.084
# Epoch Average Loss: 2.302362
# Epoch Average Loss: 2.302148
# Epoch Average Loss: 2.301860
# Validate Acc: 0.092
# Epoch Average Loss: 2.301440
# Epoch Average Loss: 2.300838
# Epoch Average Loss: 2.299975
# Validate Acc: 0.092
# Epoch Average Loss: 2.298806
# Epoch Average Loss: 2.297334
# Epoch Average Loss: 2.295508
# Validate Acc: 0.084
# Epoch Average Loss: 2.293395
# Epoch Average Loss: 2.290886
# Epoch Average Loss: 2.287850
# Validate Acc: 0.084
# Epoch Average Loss: 2.283989
# Epoch Average Loss: 2.278976
# Epoch Average Loss: 2.272831
# Validate Acc: 0.096
# Epoch Average Loss: 2.265860
# Epoch Average Loss: 2.258464
# Epoch Average Loss: 2.250795
# Validate Acc: 0.100
# Epoch Average Loss: 2.243015
# Epoch Average Loss: 2.235734
# Epoch Average Loss: 2.228561
# Validate Acc: 0.116
# Epoch Average Loss: 2.221941
# Epoch Average Loss: 2.215771
# Epoch Average Loss: 2.210106
# Validate Acc: 0.128
# Epoch Average Loss: 2.204658
# Epoch Average Loss: 2.199570
# Epoch Average Loss: 2.195448
# Validate Acc: 0.132
# Epoch Average Loss: 2.191237
# Epoch Average Loss: 2.187322
# Epoch Average Loss: 2.183451
# Validate Acc: 0.136
# Epoch Average Loss: 2.180031
# Epoch Average Loss: 2.176723
# Epoch Average Loss: 2.173462
# Validate Acc: 0.144
# Epoch Average Loss: 2.170312
# Epoch Average Loss: 2.167501
# Epoch Average Loss: 2.164217
# Validate Acc: 0.136
# Epoch Average Loss: 2.162174
# Epoch Average Loss: 2.159403
# Epoch Average Loss: 2.156761
# Validate Acc: 0.144
# Epoch Average Loss: 2.154677
# Epoch Average Loss: 2.152358
# Epoch Average Loss: 2.150206
# Validate Acc: 0.140
# Epoch Average Loss: 2.147820
# Epoch Average Loss: 2.146121
# Epoch Average Loss: 2.144268
# Validate Acc: 0.148
# Epoch Average Loss: 2.142473
# Epoch Average Loss: 2.140352
# Epoch Average Loss: 2.138664
# Validate Acc: 0.144
# Epoch Average Loss: 2.137022
# Epoch Average Loss: 2.135109
# Epoch Average Loss: 2.133628
# Validate Acc: 0.152
# Epoch Average Loss: 2.132284
# Epoch Average Loss: 2.130416
# Epoch Average Loss: 2.128504
# Validate Acc: 0.148
# Epoch Average Loss: 2.127247
# Epoch Average Loss: 2.125484
# Epoch Average Loss: 2.124153
# Validate Acc: 0.164
# Epoch Average Loss: 2.122773
# Epoch Average Loss: 2.121231
# Epoch Average Loss: 2.119545
# Validate Acc: 0.168
# Epoch Average Loss: 2.117718
# Epoch Average Loss: 2.116445
# Epoch Average Loss: 2.114523
# Validate Acc: 0.168
# Epoch Average Loss: 2.112692
# Epoch Average Loss: 2.110766
# Epoch Average Loss: 2.108844
# Validate Acc: 0.176
# Epoch Average Loss: 2.107213
# Epoch Average Loss: 2.105188
# Epoch Average Loss: 1.919094
# Epoch Average Loss: 1.917840
# Epoch Average Loss: 1.914707
# Validate Acc: 0.300
# Epoch Average Loss: 1.913333
# Epoch Average Loss: 1.911084
# Epoch Average Loss: 1.907846
# Validate Acc: 0.312
# Epoch Average Loss: 1.906043
# Epoch Average Loss: 1.903655
# Epoch Average Loss: 1.901445
# Validate Acc: 0.312
# Epoch Average Loss: 1.899529
# Epoch Average Loss: 1.896668
# Epoch Average Loss: 1.894710
# Validate Acc: 0.304
# Epoch Average Loss: 1.892916
# Epoch Average Loss: 1.890735
# Epoch Average Loss: 1.888155
# Validate Acc: 0.296
# Epoch Average Loss: 1.887200
# Epoch Average Loss: 1.884985
# Epoch Average Loss: 1.882903
# Validate Acc: 0.312
# Epoch Average Loss: 1.880692
# Epoch Average Loss: 1.879088
# Epoch Average Loss: 1.876827
# Validate Acc: 0.316
# Epoch Average Loss: 1.873234
# Epoch Average Loss: 1.872060
# Epoch Average Loss: 1.870733
# Validate Acc: 0.300
# Epoch Average Loss: 1.868962
# Epoch Average Loss: 1.866880
# Epoch Average Loss: 1.866495
# Validate Acc: 0.292
# Epoch Average Loss: 1.862407
# Epoch Average Loss: 1.861894
# Epoch Average Loss: 1.858778
# Validate Acc: 0.304
# Epoch Average Loss: 1.856929
# Epoch Average Loss: 1.855361
# Epoch Average Loss: 1.853830
# Validate Acc: 0.304
# Epoch Average Loss: 1.851812
# Epoch Average Loss: 1.849002
# Epoch Average Loss: 1.847541
# Validate Acc: 0.308
# Epoch Average Loss: 1.846672
# Epoch Average Loss: 1.843550
# Epoch Average Loss: 1.842205
# Validate Acc: 0.308
# Epoch Average Loss: 1.840613
# Epoch Average Loss: 1.838546
# Epoch Average Loss: 1.836924
# Validate Acc: 0.300
# Epoch Average Loss: 1.834845
# Epoch Average Loss: 1.833431
# Epoch Average Loss: 1.832976
# Validate Acc: 0.304
# Epoch Average Loss: 1.829212
# Epoch Average Loss: 1.828234
# Epoch Average Loss: 1.826214
# Validate Acc: 0.308
# Epoch Average Loss: 1.824425
# Epoch Average Loss: 1.822803
# Epoch Average Loss: 1.820975
# Validate Acc: 0.304
# Epoch Average Loss: 1.817001
# Epoch Average Loss: 1.816347
# Epoch Average Loss: 1.814608
# Validate Acc: 0.316
# Epoch Average Loss: 1.812830
# Epoch Average Loss: 1.811215
# Epoch Average Loss: 1.809289
# Validate Acc: 0.316
# Epoch Average Loss: 1.808077
# Epoch Average Loss: 1.805599
# Epoch Average Loss: 1.803294
# Validate Acc: 0.316
# Epoch Average Loss: 1.801728

# %% [markdown]
# ### Print the training and validation accuracies for the default hyper-parameters provided

# %%
from utils.evaluation import get_classification_accuracy

out_train = net.predict(x_train)
acc = get_classification_accuracy(out_train, y_train)
print("Training acc: ", acc)
out_val = net.predict(x_val)
acc = get_classification_accuracy(out_val, y_val)
print("Validation acc: ", acc)
# Out:
# Training acc:  0.358
# Validation acc:  0.32

# %% [markdown]
# ### Debug the training
# With the default parameters we provided above, you should get a validation accuracy of around 0.2~0.3 on the validation set. This isn't very good.
#
# One strategy for getting insight into what's wrong is to plot the training loss function and the validation accuracies during optimization.
#
# Another strategy is to visualize the weights that were learned in the first layer of the network. In most neural networks trained on visual data, the first layer weights typically show some visible structure when visualized.

# %%
# Plot the training loss function and validation accuracies
plt.subplot(2, 1, 1)
plt.plot(train_error)
plt.title("Training Loss History")
plt.xlabel("Iteration")
plt.ylabel("Loss")

plt.subplot(2, 1, 2)
# plt.plot(stats['train_acc_history'], label='train')
plt.plot(validation_accuracy, label="val")
plt.title("Classification accuracy history")
plt.xlabel("Epoch")
plt.ylabel("Classification accuracy")
plt.legend()
plt.show()

# %%
from utils.vis_utils import visualize_grid

# Credits: http://cs231n.stanford.edu/

# Visualize the weights of the network

def show_net_weights(net):
    W1 = net._modules[0].parameters[0]
    W1 = W1.reshape(3, 32, 32, -1).transpose(3, 1, 2, 0)
    plt.imshow(visualize_grid(W1, padding=3).astype("uint8"))
    plt.gca().axis("off")
    plt.show()


show_net_weights(net)

# %% [markdown]
# # Tune your hyperparameters (50%)
#
# **What's wrong?**. Looking at the visualizations above, we see that the loss is decreasing more or less linearly, which seems to suggest that the learning rate may be too low. Moreover, there is no gap between the training and validation accuracy, suggesting that the model we used has low capacity, and that we should increase its size. On the other hand, with a very large model we would expect to see more overfitting, which would manifest itself as a very large gap between the training and validation accuracy.
#
# **Tuning**. Tuning the hyperparameters and developing intuition for how they affect the final performance is a large part of using Neural Networks, so we want you to get a lot of practice. Below, you should experiment with different values of the various hyperparameters, including hidden layer size, learning rate, numer of training epochs, and regularization strength.
#
# **Approximate results**. You should be aim to achieve a classification accuracy of greater than 40% on the validation set. Our best network gets over 40% on the validation set.
#
# **Experiment**: You goal in this exercise is to get as good of a result on cifar10 as you can (40% could serve as a reference), with a fully-connected Neural Network.

# %% [markdown]
# #### Explain your hyperparameter tuning process below.
#
# #### Your Answer:

# %%
best_net_hyperparams = None  # store the best model into this

#################################################################################
# TODO: Tune hyperparameters using the validation set. Store your best trained  #
# model hyperparams in best_net.                                                #
#                                                                               #
# To help debug your network, it may help to use visualizations similar to the  #
# ones we used above; these visualizations will have significant qualitative    #
# differences from the ones we saw above for the poorly tuned network.          #
#                                                                               #
# You are now free to test different combinations of hyperparameters to build   #
# various models and test them according to the above plots and visualization   #


# TODO: Show the above plots and visualizations for the default params (already #
# done) and the best hyper-params you obtain. You only need to show this for 2  #
# sets of hyper-params.                                                         #
# You just need to store values for the hyperparameters in best_net_hyperparams #
# as a list in the order
# best_net_hyperparams = [lr, weight_decay, epoch, hidden_size]
#################################################################################
hidden_size = 2000 # HP
def init_model():
    # np.random.seed(0) # No need to fix the seed here
    l1 = Linear(input_size, hidden_size)
    l2 = Linear(hidden_size, num_classes)
    r1 = ReLU()
    softmax = Softmax()
    return Sequential([l1, r1, l2, softmax])



best_net = init_model()
optim = SGD(best_net, lr=0.07, weight_decay=0.01) # HP
epoch = 300 # HP
# Initialize the trainer class by passing the above modules
trainer = Trainer(
    dataset, optim, best_net, loss_func, epoch, batch_size, validate_interval=3
)
train_error, validation_accuracy = trainer.train()












from utils.evaluation import get_classification_accuracy

out_train = best_net.predict(x_train)
acc = get_classification_accuracy(out_train, y_train)
print("Training acc: ", acc)
out_val = best_net.predict(x_val)
acc = get_classification_accuracy(out_val, y_val)
print("Validation acc: ", acc)
# Plot the training loss function and validation accuracies
plt.subplot(2, 1, 1)
plt.plot(train_error)
plt.title("Training Loss History")
plt.xlabel("Iteration")
plt.ylabel("Loss")

plt.subplot(2, 1, 2)
# plt.plot(stats['train_acc_history'], label='train')
plt.plot(validation_accuracy, label="val")
plt.title("Classification accuracy history")
plt.xlabel("Epoch")
plt.ylabel("Classification accuracy")
plt.legend()
plt.show()


best_net_hyperparams = [0.07, 0.01, 300, 2000]

pass
# Out:
# Epoch Average Loss: 2.299462
# Validate Acc: 0.084
# Epoch Average Loss: 2.286274
# Epoch Average Loss: 2.244907
# Epoch Average Loss: 2.201666
# Validate Acc: 0.124
# Epoch Average Loss: 2.178258
# Epoch Average Loss: 2.166088
# Epoch Average Loss: 2.155030
# Validate Acc: 0.156
# Epoch Average Loss: 2.139814
# Epoch Average Loss: 2.123472
# Epoch Average Loss: 2.092490
# Validate Acc: 0.220
# Epoch Average Loss: 2.077188
# Epoch Average Loss: 2.055769
# Epoch Average Loss: 2.047732
# Validate Acc: 0.272
# Epoch Average Loss: 2.026574
# Epoch Average Loss: 2.004289
# Epoch Average Loss: 2.014848
# Validate Acc: 0.292
# Epoch Average Loss: 1.996531
# Epoch Average Loss: 2.003741
# Epoch Average Loss: 1.960254
# Validate Acc: 0.308
# Epoch Average Loss: 1.965005
# Epoch Average Loss: 1.947338
# Epoch Average Loss: 1.943646
# Validate Acc: 0.308
# Epoch Average Loss: 1.912581
# Epoch Average Loss: 1.921174
# Validate Acc: 0.436
# Epoch Average Loss: 1.378693
# Epoch Average Loss: 1.330099
# Epoch Average Loss: 1.406682
# Validate Acc: 0.416
# Epoch Average Loss: 1.336566
# Epoch Average Loss: 1.348943
# Epoch Average Loss: 1.310034
# Validate Acc: 0.448
# Epoch Average Loss: 1.314779
# Epoch Average Loss: 1.318987
# Epoch Average Loss: 1.332190
# Validate Acc: 0.440
# Epoch Average Loss: 1.331328
# Epoch Average Loss: 1.382897
# Epoch Average Loss: 1.375280
# Validate Acc: 0.376
# Epoch Average Loss: 1.317945
# Epoch Average Loss: 1.332502
# Epoch Average Loss: 1.353650
# Validate Acc: 0.412
# Epoch Average Loss: 1.314274
# Epoch Average Loss: 1.318289
# Epoch Average Loss: 1.304658
# Validate Acc: 0.428
# Epoch Average Loss: 1.361621
# Epoch Average Loss: 1.318373
# Epoch Average Loss: 1.295508
# Validate Acc: 0.400
# Epoch Average Loss: 1.343156
# Epoch Average Loss: 1.306417
# Epoch Average Loss: 1.318891
# Validate Acc: 0.372
# Epoch Average Loss: 1.328166
# Epoch Average Loss: 1.314992
# Epoch Average Loss: 1.356851
# Validate Acc: 0.416
# Epoch Average Loss: 1.395621
# Epoch Average Loss: 1.349583
# Epoch Average Loss: 1.325922
# Validate Acc: 0.428
# Epoch Average Loss: 1.343539
# Epoch Average Loss: 1.319606
# Epoch Average Loss: 1.333175
# Validate Acc: 0.388
# Epoch Average Loss: 1.305882
# Epoch Average Loss: 1.281322
# Epoch Average Loss: 1.285612
# Validate Acc: 0.416
# Epoch Average Loss: 1.305814
# Epoch Average Loss: 1.334076
# Epoch Average Loss: 1.313599
# Validate Acc: 0.432
# Epoch Average Loss: 1.348798
# Epoch Average Loss: 1.327310
# Epoch Average Loss: 1.316457
# Validate Acc: 0.416
# Epoch Average Loss: 1.278922
# Epoch Average Loss: 1.301711
# Epoch Average Loss: 1.328765
# Validate Acc: 0.436
# Epoch Average Loss: 1.298019
# Epoch Average Loss: 1.328137
# Epoch Average Loss: 1.292173
# Validate Acc: 0.436
# Epoch Average Loss: 1.357278
# Epoch Average Loss: 1.334672
# Epoch Average Loss: 1.319688
# Validate Acc: 0.440
# Epoch Average Loss: 1.285234
# Epoch Average Loss: 1.321125
# Epoch Average Loss: 1.286085
# Validate Acc: 0.376
# Epoch Average Loss: 1.313040
# Epoch Average Loss: 1.298048
# Epoch Average Loss: 1.300680
# Validate Acc: 0.428
# Epoch Average Loss: 1.283447
# Epoch Average Loss: 1.282892
# Epoch Average Loss: 1.318146
# Validate Acc: 0.448
# Epoch Average Loss: 1.296188
# Epoch Average Loss: 1.306668
# Epoch Average Loss: 1.322780
# Validate Acc: 0.428
# Epoch Average Loss: 1.283491
# Epoch Average Loss: 1.309139
# Training acc:  0.5858
# Validation acc:  0.432

# %%
best_net_hyperparams = [0.07, 0.01, 300, 2000]
show_net_weights(best_net)

# %% [markdown]
# # Run on the test set (30%)
# When you are done experimenting, you should evaluate your final trained network on the test set; you should get above 35%.

# %%
test_acc = (best_net.predict(x_test) == y_test).mean()
# Out:
# Test accuracy:  0.39
